# %%
import pandas as pd

# %%
DATA_PATH_TRAIN = '../data/energy_preprocessed_train.csv'
DATA_PATH_TEST = '../data/energy_preprocessed_test.csv'

# %%
df1 = pd.read_csv(DATA_PATH_TRAIN)
df2 = pd.read_csv(DATA_PATH_TEST)

print((df1.shape[0] + df2.shape[0], df1.shape[1]))
# Out:
# (19735, 32)
